# %%
#importando libs
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# #upload de arquivos
# from google.colab import files
# arq = files.upload()

# %%
# Carregando o DF
df = pd.read_excel('AdventureWorks.xlsx')

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
# quantidade de linhas x colunas
df.shape
# Out:
# (904, 16)

# %%
# verificando os tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# avaliacao estatística do DF
df.describe()
# Out:
#           ID Loja   ID Produto  ...  Valor Desconto   Valor Venda
# count  904.000000   904.000000  ...      904.000000    904.000000
# mean   270.015487  1225.238938  ...      689.123294   6620.139538
# std     50.955280   706.698742  ...      822.363117   4319.407257
# min    199.000000   366.000000  ...        0.000000    159.840000
# 25%    199.000000   384.000000  ...        0.000000   3920.000000
# 50%    306.000000  1202.000000  ...      461.166000   5798.700000
# 75%    307.000000  1226.000000  ...     1005.075000   7986.000000
# max    307.000000  2497.000000  ...     6272.000000  29400.000000
#
# [8 rows x 8 columns]

# %%
# Data da primeira venda registrada
df['Data Venda'].min()
# Out:
# Timestamp('2008-01-02 00:00:00')

# %%
# Data da ultima venda registrada
df['Data Venda'].max()
# Out:
# Timestamp('2009-12-31 00:00:00')

# %%
# Receita total do período
round(df["Valor Venda"].sum(),2)
# Out:
# 5984606.14

# %%
# qual o Custo Total por venda?
df['Custo Total'] = df['Custo Unitário'].mul(df["Quantidade"]) # Criando a coluna custo total

# %%
# qual o custo total do período?
df["Custo Total"].sum()
# Out:
# 2486783.05

# %%
# Qual foi o lucro bruto?
df["Valor Venda"].sum() - df["Custo Total"].sum()
# Out:
# 3497823.0926

# %%
df['lucro'] = df['Valor Venda'] - df['Custo Total']

# %%
df.head(5)
# Out:
#   Data Venda Data Envio  ID Loja  ...  Cor  Custo Total    lucro
# 0 2008-05-09 2008-05-29      199  ...  Red      2091.48  2456.52
# 1 2008-05-12 2008-05-17      306  ...  Red      2091.48  2456.52
# 2 2008-05-14 2008-05-20      306  ...  Red      2091.48  2456.52
# 3 2008-05-21 2008-05-27      306  ...  Red      2091.48  2456.52
# 4 2008-06-20 2008-06-27      306  ...  Red      2091.48  2456.52
#
# [5 rows x 18 columns]

# %%
# total lucro
round(df['lucro'].sum(),2)
# Out:
# 3497823.09

# %%
# criando uma coluna para calcular o tempo de envio
df["tempo_envio"] = (df['Data Envio'] - df['Data Venda']).dt.days
# df["tempo_envio"] = df['Data Envio'] - df['Data Venda']

# %%
# df.drop(columns=['tempo_envio'])
df.head(5)
# Out:
#   Data Venda Data Envio  ID Loja  ...  Custo Total    lucro tempo_envio
# 0 2008-05-09 2008-05-29      199  ...      2091.48  2456.52          20
# 1 2008-05-12 2008-05-17      306  ...      2091.48  2456.52           5
# 2 2008-05-14 2008-05-20      306  ...      2091.48  2456.52           6
# 3 2008-05-21 2008-05-27      306  ...      2091.48  2456.52           6
# 4 2008-06-20 2008-06-27      306  ...      2091.48  2456.52           7
#
# [5 rows x 19 columns]

# %%
df.head(5)
# Out:
#   Data Venda Data Envio  ID Loja  ...  Custo Total    lucro tempo_envio
# 0 2008-05-09 2008-05-29      199  ...      2091.48  2456.52          20
# 1 2008-05-12 2008-05-17      306  ...      2091.48  2456.52           5
# 2 2008-05-14 2008-05-20      306  ...      2091.48  2456.52           6
# 3 2008-05-21 2008-05-27      306  ...      2091.48  2456.52           6
# 4 2008-06-20 2008-06-27      306  ...      2091.48  2456.52           7
#
# [5 rows x 19 columns]

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# Custo Total              float64
# lucro                    float64
# tempo_envio                int64
# dtype: object

# %%
df["tempo_envio"].dtypes
# Out:
# dtype('int64')

# %%
round(df.groupby("Marca")["tempo_envio"].mean(),2)
# Out:
# Marca
# Adventure Works    8.66
# Contoso            8.47
# Fabrikam           8.51
# Name: tempo_envio, dtype: float64

# %%
# Existem valores ausentes
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo Total       0
# lucro             0
# tempo_envio       0
# dtype: int64

# %%
# Vamos agrupar por ano e por marca
df.groupby([df['Data Venda'].dt.year, "Marca"])["lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: lucro, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Resetando o index
lucro_ano = df.groupby([df['Data Venda'].dt.year, "Marca"])["lucro"].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
# Qual o total de produtos Vendidos?
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
# Qual o total de produtos Vendidos?
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=True).plot.barh(title='Total de Produtos Vendidos')
plt.xlabel('Total');
plt.ylabel('Produto');

# %%
df.groupby(df['Data Venda'].dt.year)['lucro'].sum().plot.bar('Lucro / Ano');
plt.xlabel('Ano');
plt.ylabel('Receita');

# %%
df.groupby(df['Data Venda'].dt.year)['lucro'].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: lucro, dtype: float64

# %%
#Selecionando apenas as vendas de 2009
df2009 = df[df["Data Venda"].dt.year == 2009]

# %%
df2009.head()
# Out:
#    Data Venda Data Envio  ...                lucro  tempo_envio
# 11 2009-05-02 2009-05-14  ...             2,456.52           12
# 12 2009-05-16 2009-05-27  ...             2,456.52           11
# 13 2009-05-31 2009-06-12  ...             2,456.52           12
# 14 2009-06-28 2009-07-11  ...             2,456.52           13
# 15 2009-07-08 2009-07-12  ...             2,456.52            4
#
# [5 rows x 19 columns]

# %%
df2009.groupby(df2009["Data Venda"].dt.month)["lucro"].sum().plot(title='Lucro x Mes (2009)',marker="o");
plt.xlabel("Mês")
plt.ylabel("Lucro");
plt.legend();

# %%
df2009.groupby('Marca')['lucro'].sum().plot.bar(title='Lucro x Marca');
plt.xlabel('Marca');
plt.ylabel('Lucro');

# %%
df2009.groupby('Classe')['lucro'].sum().plot.bar(title='Lucro x Classe');
plt.xlabel('Classe');
plt.ylabel('Lucro');
plt.xticks(rotation='horizontal');

# %%
df.columns
# Out:
# Index(['Data Venda', 'Data Envio', 'ID Loja', 'ID Produto', 'ID Cliente',
#        'No. Venda', 'Custo Unitário', 'Preço Unitário', 'Quantidade',
#        'Valor Desconto', 'Valor Venda', 'Produto', 'Fabricante', 'Marca',
#        'Classe', 'Cor', 'Custo Total', 'lucro', 'tempo_envio'],
#       dtype='object')

# %%
df['tempo_envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: tempo_envio, dtype: float64

# %%
# gráfico boxplot
plt.boxplot(df['tempo_envio']);

# %%
# Histograma
plt.hist(df['tempo_envio']);

# %%
# tempo mínimo envio
df['tempo_envio'].min()
# Out:
# 4

# %%
# tempo mínimo envio
df['tempo_envio'].max()
# Out:
# 20

# %%
# tempo total envio
df[df['tempo_envio'] == 20]
# Out:
#   Data Venda Data Envio  ...                lucro  tempo_envio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
#
# [1 rows x 19 columns]

# %%
df.to_csv('df_vendas_novo.csv', index=False)
