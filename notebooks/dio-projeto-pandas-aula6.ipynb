# %%
import pandas as pd

# %%
def load_concat():
  df1 = pd.read_excel('Aracaju.xlsx')
  df2 = pd.read_excel('Fortaleza.xlsx')
  df3 = pd.read_excel('Natal.xlsx')
  df4 = pd.read_excel('Recife.xlsx')
  df5 = pd.read_excel('Salvador.xlsx')

  df = pd.concat([df1,df2,df3,df4,df5])

  return df

# %%
df = load_concat()

# %%
df
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 0     Aracaju 2018-01-01  142.00    1520     1
# 1     Aracaju 2018-01-01   14.21    1522     6
# 2     Aracaju 2018-01-01   71.55    1520     1
# 3     Aracaju 2018-01-01    3.01    1521     7
# 4     Aracaju 2018-01-01   24.51    1522     8
# ..        ...        ...     ...     ...   ...
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3
#
# [894 rows x 5 columns]

# %%
df["Data"] = df["Data"].astype('int64')

# %%
df.dtypes
# Out:
# Cidade     object
# Data        int64
# Vendas    float64
# LojaID      int64
# Qtde        int64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    223929.72
# Name: Receita, dtype: float64

# %%
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda
# 199   Salvador 2019-01-02  153.87    1036     3   461.61       2019
# 12      Recife 2019-01-01   17.48     982     2    34.96       2019
# 189      Natal 2019-01-02  139.73    1037     2   279.46       2019
# 182      Natal 2019-01-02    6.60    1037     2    13.20       2019
# 101  Fortaleza 2019-01-01   11.67    1005     4    46.68       2019

# %%
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  Ano_Venda  mes_venda  dia_venda
# 88      Recife 2019-01-01  180.24  ...       2019          1          1
# 128  Fortaleza 2019-03-02   38.70  ...       2019          3          2
# 87       Natal 2019-01-02  135.19  ...       2019          1          2
# 158   Salvador 2019-01-02  183.64  ...       2019          1          2
# 115  Fortaleza 2019-03-02   12.23  ...       2019          3          2
#
# [5 rows x 9 columns]

# %%
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  mes_venda  dia_venda  diferenca_dias
# 57       Natal 2019-02-24  425.00  ...          2         24        419 days
# 40   Fortaleza 2019-02-13   19.13  ...          2         13        408 days
# 116  Fortaleza 2019-03-02   79.10  ...          3          2        425 days
# 79    Salvador 2019-01-01   19.02  ...          1          1        365 days
# 142      Natal 2019-01-02    7.12  ...          1          2        366 days
#
# [5 rows x 10 columns]

# %%
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  dia_venda  diferenca_dias  trimestre_venda
# 197   Salvador 2019-01-02   10.45  ...          2        366 days                1
# 85       Natal 2019-01-02   16.88  ...          2        366 days                1
# 93   Fortaleza 2019-01-01   35.25  ...          1        365 days                1
# 44      Recife 2019-01-01  142.21  ...          1        365 days                1
# 14       Natal 2018-06-03  660.00  ...          3        153 days                2
#
# [5 rows x 11 columns]

# %%
df.groupby(["Ano_Venda", "trimestre_venda"])["Qtde"].sum()
# Out:
# Ano_Venda  trimestre_venda
# 2018       1                   690
#            2                    41
#            3                    25
#            4                    19
# 2019       1                  2129
#            2                    12
# Name: Qtde, dtype: int64

# %%
filtro1 = df["Data"].dt.month == 3
filtro2 = df["Data"].dt.year == 2019
df.loc[filtro1 & filtro2].count()
# Out:
# Cidade             121
# Data               121
# Vendas             120
# LojaID             121
# Qtde               121
# Receita            120
# Ano_Venda          121
# mes_venda          121
# dia_venda          121
# diferenca_dias     121
# trimestre_venda    121
# dtype: int64
