# %%
import pandas as pd

# %%
def load_concat():
  df1 = pd.read_excel('Aracaju.xlsx')
  df2 = pd.read_excel('Fortaleza.xlsx')
  df3 = pd.read_excel('Natal.xlsx')
  df4 = pd.read_excel('Recife.xlsx')
  df5 = pd.read_excel('Salvador.xlsx')

  df = pd.concat([df1,df2,df3,df4,df5])

  return df

# %%
df = load_concat()

# %%
df5.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-582e4cbd163b> in <module>()
# ----> 1 df5.head()
#
# NameError: name 'df5' is not defined

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5cc0934cc03c> in <module>()
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 94      Recife 2019-01-01   24.70     982     3
# 131      Natal 2019-01-02   63.48    1037     3
# 19   Fortaleza 2019-01-01   18.86    1002     3
# 108    Aracaju 2018-01-01   31.94    1520     8
# 104  Fortaleza 2019-01-01   40.50    1005     2
# 187   Salvador 2019-01-02    3.85    1035     3
# 126    Aracaju 2018-01-01   13.41    1520     7
# 115  Fortaleza 2019-03-02   12.23     981     3
# 2    Fortaleza 2019-02-10   35.33    1004     3
# 30   Fortaleza 2019-01-01   39.13    1005     6

# %%
df['LojaID'] = df['LojaID'].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 1       Recife 2019-01-01   11.44    983     1
# 96   Fortaleza 2019-01-01   23.31   1004     4
# 19   Fortaleza 2019-01-01   18.86   1002     3
# 29   Fortaleza 2019-01-01  186.29   1005     2
# 26       Natal 2018-07-20  370.00    853     3
# 103     Recife 2019-01-01   41.65    982     3
# 199      Natal 2019-01-02  153.87   1036     3
# 146   Salvador 2019-01-02  149.88   1037     1
# 32    Salvador 2019-01-01  151.27   1035     1
# 2    Fortaleza 2019-02-10   35.33   1004     3

# %%
df.isnull().sum()
# Out:
# Cidade     0
# Data       0
# Vendas    20
# LojaID     0
# Qtde       0
# dtype: int64

# %%
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df['Vendas'].mean()
# Out:
# 123.78638443935907

# %%
filtro = df.Vendas == 123.78638443935907
df.loc[filtro]
# Out:
#         Cidade       Data      Vendas  LojaID  Qtde
# 4    Fortaleza 2019-01-01  123.786384    1004     6
# 5    Fortaleza 2019-01-01  123.786384    1002     5
# 6    Fortaleza 2019-01-01  123.786384    1003     4
# 7    Fortaleza 2019-02-11  123.786384    1003     2
# 8    Fortaleza 2019-02-11  123.786384    1005     1
# 9    Fortaleza 2019-01-01  123.786384    1002     6
# 10   Fortaleza 2019-01-01  123.786384    1002     4
# 11   Fortaleza 2019-01-01  123.786384    1003     3
# 12   Fortaleza 2019-01-01  123.786384    1004     2
# 13   Fortaleza 2019-02-12  123.786384    1003     4
# 14   Fortaleza 2019-01-12  123.786384    1005     1
# 4       Recife 2019-02-14  123.786384     983     7
# 5       Recife 2019-01-01  123.786384     980     3
# 6       Recife 2019-01-01  123.786384     981     6
# 128     Recife 2019-03-02  123.786384     982     4
# 3     Salvador 2019-02-10  123.786384    1037     3
# 48    Salvador 2019-01-01  123.786384    1035     2
# 93    Salvador 2019-01-01  123.786384    1037     1
# 166   Salvador 2019-01-02  123.786384    1035     3
# 188   Salvador 2019-01-02  123.786384    1035     3

# %%
df["Vendas"].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
filtro = df.Vendas == 0
df.loc[filtro]
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 4    Fortaleza 2019-01-01     0.0    1004     6
# 5    Fortaleza 2019-01-01     0.0    1002     5
# 6    Fortaleza 2019-01-01     0.0    1003     4
# 7    Fortaleza 2019-02-11     0.0    1003     2
# 8    Fortaleza 2019-02-11     0.0    1005     1
# 9    Fortaleza 2019-01-01     0.0    1002     6
# 10   Fortaleza 2019-01-01     0.0    1002     4
# 11   Fortaleza 2019-01-01     0.0    1003     3
# 12   Fortaleza 2019-01-01     0.0    1004     2
# 13   Fortaleza 2019-02-12     0.0    1003     4
# 14   Fortaleza 2019-01-12     0.0    1005     1
# 4       Recife 2019-02-14     0.0     983     7
# 5       Recife 2019-01-01     0.0     980     3
# 6       Recife 2019-01-01     0.0     981     6
# 128     Recife 2019-03-02     0.0     982     4
# 3     Salvador 2019-02-10     0.0    1037     3
# 48    Salvador 2019-01-01     0.0    1035     2
# 93    Salvador 2019-01-01     0.0    1037     1
# 166   Salvador 2019-01-02     0.0    1035     3
# 188   Salvador 2019-01-02     0.0    1035     3

# %%
load_concat()

# %%
df.isnull().sum()
# Out:
# Cidade     0
# Data       0
# Vendas    20
# LojaID     0
# Qtde       0
# dtype: int64

# %%
df.count()
# Out:
# Cidade    894
# Data      894
# Vendas    874
# LojaID    894
# Qtde      894
# dtype: int64

# %%
df .dropna(inplace=True)

# %%
df.count()
# Out:
# Cidade    874
# Data      874
# Vendas    874
# LojaID    874
# Qtde      874
# dtype: int64

# %%
df.dropna(subset=["Vendas"], inplace=True)

# %%
df.count()
# Out:
# Cidade    874
# Data      874
# Vendas    874
# LojaID    874
# Qtde      874
# dtype: int64

# %%
df = load_concat()

# %%
df.count()
# Out:
# Cidade    894
# Data      894
# Vendas    874
# LojaID    894
# Qtde      894
# dtype: int64

# %%
df.dropna(how='all', inplace=True)

# %%
df.count()
# Out:
# Cidade    894
# Data      894
# Vendas    874
# LojaID    894
# Qtde      894
# dtype: int64

# %%
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita
# 0     Aracaju 2018-01-01  142.00    1520     1   142.00
# 1     Aracaju 2018-01-01   14.21    1522     6    85.26
# 2     Aracaju 2018-01-01   71.55    1520     1    71.55
# 3     Aracaju 2018-01-01    3.01    1521     7    21.07
# 4     Aracaju 2018-01-01   24.51    1522     8   196.08
# ..        ...        ...     ...     ...   ...      ...
# 235  Salvador 2019-01-03   41.84    1034     1    41.84
# 236  Salvador 2019-01-03  126.29    1035     3   378.87
# 237  Salvador 2019-01-03   38.06    1036     3   114.18
# 238  Salvador 2019-01-03  139.64    1035     1   139.64
# 239  Salvador 2019-01-03  161.41    1037     3   484.23
#
# [894 rows x 6 columns]

# %%
df['Receitas/Vendas'] = df['Receita'] / df['Vendas']

# %%
df.sample(10)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Receitas/Vendas
# 115      Natal 2019-01-02  202.33    1035     2   404.66              2.0
# 140   Salvador 2019-03-02   20.79    1036     2    41.58              2.0
# 166      Natal 2019-01-02  111.72    1035     3   335.16              3.0
# 14     Aracaju 2018-01-01  148.21    1521     3   444.63              3.0
# 147   Salvador 2019-01-02   34.50    1035     1    34.50              1.0
# 135  Fortaleza 2019-03-02   10.79     983     5    53.95              5.0
# 125     Recife 2019-03-02   37.60     983     4   150.40              4.0
# 130     Recife 2019-03-02   12.36     983     4    49.44              4.0
# 161      Natal 2019-01-02    5.80    1036     1     5.80              1.0
# 221      Natal 2019-01-02  142.23    1035     2   284.46              2.0

# %%
df['Receita'].max()
# Out:
# 3544.0

# %%
df['Receita'].min()
# Out:
# 3.34

# %%
df.nlargest(3, 'Receita')
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde  Receita  Receitas/Vendas
# 7   Natal 2019-03-18   886.0     853     4   3544.0              4.0
# 51  Natal 2018-01-21   859.0     852     4   3436.0              4.0
# 55  Natal 2019-01-08   859.0     854     4   3436.0              4.0

# %%
df.nsmallest(3, 'Receita')
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde  Receita  Receitas/Vendas
# 118  Aracaju 2018-01-01    3.34    1522     1     3.34              1.0
# 65    Recife 2019-01-01    4.01     981     1     4.01              1.0
# 92     Natal 2019-01-02    4.57    1035     1     4.57              1.0

# %%
df.groupby("Cidade")['Receita'].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     35698.31
# Natal        167227.52
# Recife        51504.09
# Salvador      38928.08
# Name: Receita, dtype: float64

# %%
df.groupby("Cidade")['Receita'].sum().sort_values()
# Out:
# Cidade
# Fortaleza     35698.31
# Salvador      38928.08
# Aracaju       48748.25
# Recife        51504.09
# Natal        167227.52
# Name: Receita, dtype: float64
